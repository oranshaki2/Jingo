# %% [markdown]
# # English Learning App - Word Sense Filtering
# This notebook filters words from song lyrics that don't match their intended semantic meaning based on translation into Hebrew.

# %%
import pandas as pd
import ast
import re
import os
from sentence_transformers import SentenceTransformer, util
from googletrans import Translator
import time
from difflib import SequenceMatcher
from category_in_hebrew import intended_hebrew

# --- General Configuration ---
BATCH_SIZE = 500
INPUT_PATH = '../data/songs_category_before_tran2.csv'
OUTPUT_PATH = '../data/filtered_songs_disambiguated2.csv'

# --- Load model and translation tools ---
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')
translator = Translator()
translation_cache = {}

# Retry mechanism for Google Translate to handle rate limits/errors
def translate_with_retry(sentence, retries=3, delay=1):
    for attempt in range(retries):
        try:
            return translator.translate(sentence, src='en', dest='he').text
        except Exception as e:
            print(f"Translation failed (attempt {attempt+1}): {e}")
            time.sleep(delay)
    return None

# Use cache to avoid redundant translations
def translate_with_cache(sentence):
    if sentence in translation_cache:
        return translation_cache[sentence]
    translated = translate_with_retry(sentence)
    if translated:
        translation_cache[sentence] = translated
    return translated

# Basic sentence splitter
def split_sentences(text):
    return re.split(r'[.!?\n]', text)

# Check if the word is used in the intended sense
def is_correct_sense(word, sentence, intended_hebrew_meaning, threshold=0.75):
    translated = translate_with_cache(sentence)
    if not translated:
        return False

    # Direct match
    if intended_hebrew_meaning in translated:
        print(f"\n✔️ {word.upper()} found via direct match: '{intended_hebrew_meaning}' in '{translated}'")
        return True

    # Fuzzy string match
    similarity_str = SequenceMatcher(None, translated, intended_hebrew_meaning).ratio()
    if similarity_str > 0.85:
        print(f"\n✔️ {word.upper()} found via fuzzy string match ({similarity_str:.2f})")
        return True

    # Semantic similarity using sentence embeddings
    try:
        emb_sentence = model.encode(translated, convert_to_tensor=True)
        emb_meaning = model.encode(intended_hebrew_meaning, convert_to_tensor=True)
        similarity = util.pytorch_cos_sim(emb_sentence, emb_meaning).item()
        print(f"\nWord: {word}")
        print(f"Original Sentence: {sentence}")
        print(f"Translated (HE): {translated}")
        print(f"Intended (HE): {intended_hebrew_meaning}")
        print(f"Similarity: {similarity:.4f} — {'✔️ KEEP' if similarity >= threshold else '❌ SKIP'}")
        return similarity >= threshold
    except Exception as e:
        print(f"Embedding failed: {e}")
        return False

# --- Load data ---
df = pd.read_csv(INPUT_PATH)

# Load previously processed data if exists
if os.path.exists(OUTPUT_PATH):
    existing_df = pd.read_csv(OUTPUT_PATH)
    processed_count = len(existing_df)
else:
    existing_df = pd.DataFrame()
    processed_count = 0

print(f"Processed so far: {processed_count}")

# Select the next batch of songs to process
df_batch = df.iloc[processed_count:processed_count + BATCH_SIZE]

if df_batch.empty:
    print("✅ All songs processed.")
    exit()

filtered_rows = []

# --- Process current batch ---
for idx, row in df_batch.iterrows():
    lyrics = row['cleaned_lyrics'].lower()
    updated_groups = []
    category_groups = ast.literal_eval(row['category_words'])
    sentences = split_sentences(lyrics)

    for group in category_groups:
        filtered_group = []
        for word in group:
            found = False
            for category_dict in intended_hebrew.values():
                if word in category_dict:
                    intended_hebrew_meaning = category_dict[word]
                    sentence = next((s.strip() for s in sentences if word in s), None)
                    if sentence and is_correct_sense(word, sentence, intended_hebrew_meaning):
                        filtered_group.append(word)
                    found = True
                    break
            if not found:
                filtered_group.append(word)

        if filtered_group:
            updated_groups.append(filtered_group)

    row['category_words'] = str(updated_groups)
    filtered_rows.append(row)

# --- Save results ---
filtered_df = pd.DataFrame(filtered_rows)
combined_df = pd.concat([existing_df, filtered_df], ignore_index=True)
combined_df.to_csv(OUTPUT_PATH, index=False)

print(f"✅ Batch processed and saved: {processed_count} ➡ {processed_count + len(filtered_df)}")
# Out:
# Processed so far: 16000
#
# ✔️ HAND found via direct match: 'יד' in 'היא פשוט חייכה והחזיקה את ידי'
#
# Word: eye
# Original Sentence: caught her eye
# Translated (HE): תפס את עיניה
# Intended (HE): עין
# Similarity: 0.8758 — ✔️ KEEP
#
# ✔️ HAIR found via direct match: 'שיער' in 'חותכים את השיער וקבלו עבודה'
#
# ✔️ HOME found via direct match: 'בית' in 'נהגתי ללכת אותך הביתה לפעמים אבל זה אומר'
#
# ✔️ BROTHER found via direct match: 'אח' in 'האמהות שלנו אמרו שאנחנו יכולים להיות אחות ואח'
#
# ✔️ MOTHERS found via direct match: 'אמהות' in 'האמהות שלנו אמרו שאנחנו יכולים להיות אחות ואח'
#
# ✔️ SISTER found via direct match: 'אחות' in 'האמהות שלנו אמרו שאנחנו יכולים להיות אחות ואח'
#
# ✔️ BABY found via direct match: 'תינוק' in 'אוי מה אתה עושה תינוק יום ראשון'
#
# ✔️ HOUSE found via direct match: 'בית' in 'הבית שלך היה קטן מאוד'
#
# ✔️ SKIN found via direct match: 'עור' in 'העור נמתח חזק על עצמות לחיים גבוהות'
#
# ✔️ EYES found via direct match: 'עיניים' in 'ואלפי קווי יובש זעירים המכות דרך לפינות העיניים שלך'
#
# Word: eye
# Original Sentence: and thousands of tiny dryness lines beating a path to the corners of your eyes
# Translated (HE): ואלפי קווי יובש זעירים המכות דרך לפינות העיניים שלך
# Intended (HE): עין
# Similarity: 0.6234 — ❌ SKIP
#
# ✔️ HEAD found via direct match: 'ראש' in 'נהגתי לחבר את ההודעות הקריטיות שלי בראשי'
#
# ✔️ CHEST found via direct match: 'חזה' in 'מעל המקום בו נגעתי לראשונה בחזה ילדה'
#
# ✔️ STOMACH found via direct match: 'בטן' in 'בטן בחזה החוצה'
#
# ✔️ CHEST found via direct match: 'חזה' in 'בטן בחזה החוצה'
#
# ✔️ HEAD found via direct match: 'ראש' in 'למה לחיות בעולם כשאתה יכול לחיות בראש שלך'
#
# ✔️ SKIRT found via direct match: 'חצאית' in 'כשאתה מרים את חצאית העיפרון שלך'
#
# Word: watch
# Original Sentence: and watch my conscience disappear now baby
# Translated (HE): וצפה במצפוני נעלם עכשיו מותק
# Intended (HE): שעון
# Similarity: 0.7026 — ❌ SKIP
#
# Word: veil
# Original Sentence: like a veil before my eyes
# Translated (HE): כמו רעלה לנגד עיניי
# Intended (HE): צעיף
# Similarity: 0.7859 — ✔️ KEEP
#
# ✔️ DAD found via direct match: 'אבא' in 'ועכשיו אני עובד על אבא שלך'
#
# ✔️ MOTHER found via direct match: 'אמא' in 'אבל נישקתי את אמא שלך פעמיים'
#
# Word: baby
# Original Sentence: and watch my conscience disappear now baby
# Translated (HE): וצפה במצפוני נעלם עכשיו מותק
# Intended (HE): תינוק
# Similarity: 0.8143 — ✔️ KEEP
#
# ✔️ HOUSE found via direct match: 'בית' in 'ואז אני יכול לראות את הבית שלי מכאן'
#
# ✔️ CHILDREN found via direct match: 'ילדים' in 'בעוד שילדים משחקים בחוץ'
#
# ✔️ CHILD found via direct match: 'ילד' in 'והיה לו חלום על ילד קטן'
#
# ✔️ MOTHERS found via direct match: 'אמהות' in 'ולחכות שאמהותיהן יסיימו עם האוהבים'
#
# ✔️ HOME found via direct match: 'בית' in 'הת'ר רחל צ'לסי ליין תחזור הביתה'
#
# ✔️ SISTER found via direct match: 'אחות' in 'אתה לא אח אחות'
#
# Word: mother
# Original Sentence: youre not his mother
# Translated (HE): אתה לא אמו
# Intended (HE): אמא
# Similarity: 0.9060 — ✔️ KEEP
#
# ✔️ BABY found via direct match: 'תינוק' in 'כן למד את התינוק שלך איך להתרחק'
#
# ✔️ BROTHER found via direct match: 'אח' in 'אתה לא אח אחות'
#
# Word: hurt
# Original Sentence: kissed her where she said it hurt
# Translated (HE): נישקה אותה איפה שהיא אמרה שזה כואב
# Intended (HE): פגוע
# Similarity: 0.7145 — ❌ SKIP
#
# ✔️ TIRED found via direct match: 'עייף' in 'אה הרגשתי חולה ועייף'
#
# Word: kind
# Original Sentence: i guess i kind of missed you
# Translated (HE): אני מניח שאני די התגעגעתי אליך
# Intended (HE): אדיב
# Similarity: 0.7750 — ✔️ KEEP
#
# ✔️ SICK found via direct match: 'חולה' in 'אה הרגשתי חולה ועייף'
#
# ✔️ LOVE found via direct match: 'אהבה' in 'לאן שהאהבה הלכה אני צריך לדעת'
#
# ✔️ BROTHER found via direct match: 'אח' in 'אח האח'
#
# ✔️ FATHER found via direct match: 'אבא' in 'אבא אבא'
#
# ✔️ HOUSE found via direct match: 'בית' in 'ואני אקח את הראשון בכל בית בעיר'
#
# ✔️ MOTHER found via direct match: 'אמא' in 'אמא אמא'
#
# ✔️ SISTERS found via direct match: 'אחיות' in 'אני אקח את האחיות שלך ואשים אותן'
#
# Word: knees
# Original Sentence: yeah i brought it to its knees
# Translated (HE): כן הבאתי אותו על ברכיו
# Intended (HE): ברכיים
# Similarity: 0.8782 — ✔️ KEEP
#
# ✔️ HAND found via direct match: 'יד' in 'ולקחת אותך ביד אוי אלוהים'
#
# ✔️ ARMS found via direct match: 'זרועות' in 'בזרועותיו של איש אחר'
#
# ✔️ SORROW found via direct match: 'צער' in 'אין כעס אין אשמה ושום צער'
#
# ✔️ ANGER found via direct match: 'כעס' in 'אין כעס אין אשמה ושום צער'
#
# Word: love
# Original Sentence: i love the way you do it
# Translated (HE): אני אוהב את הדרך בה אתה עושה את זה
# Intended (HE): אהבה
# Similarity: 0.7976 — ✔️ KEEP
#
# ✔️ QUIET found via direct match: 'שקט' in 'אם אתה שקט אתה יכול לצפות אם אתה רוצה'
#
# ✔️ GUILT found via direct match: 'אשמה' in 'אין כעס אין אשמה ושום צער'
#
# ✔️ LOST found via direct match: 'אבוד' in 'עש לאור אבוד כמו שנמצא'
#
# Word: tender
# Original Sentence: a love of tender age
# Translated (HE): אהבה לגיל רך
# Intended (HE): עדין
# Similarity: 0.8497 — ✔️ KEEP
#
# ✔️ LOVE found via direct match: 'אהבה' in 'אהבה לגיל רך'
#
# ✔️ SKIN found via direct match: 'עור' in 'ואתה תלבש את העצמות שלי ואת העור שלי'
#
# Word: eyes
# Original Sentence: through his dusk and dawning eyes
# Translated (HE): דרך בין ערביים ועיניו המפוארות
# Intended (HE): עיניים
# Similarity: 0.8536 — ✔️ KEEP
#
# ✔️ BLOOD found via direct match: 'דם' in 'ואני אתן את בשר שלי ואת הדם שלי ואת המח'
#
# Word: shoulders
# Original Sentence: and from the mount of his shoulders
# Translated (HE): ומהר כתפיו
# Intended (HE): כתפיים
# Similarity: 0.9261 — ✔️ KEEP
#
# Word: mouth
# Original Sentence: and from the mouth of my lover
# Translated (HE): ומפי המאהב שלי
# Intended (HE): פה
# Similarity: 0.7003 — ❌ SKIP
#
# ✔️ BONES found via direct match: 'עצמות' in 'ואתה תלבש את העצמות שלי ואת העור שלי'
#
# Word: love
# Original Sentence: girl of my heart i love you so
# Translated (HE): ילדה של ליבי אני כל כך אוהבת אותך
# Intended (HE): אהבה
# Similarity: 0.7580 — ✔️ KEEP
#
# Word: tired
# Original Sentence: if you got tired and said goodbye
# Translated (HE): אם התעייפת ונפרדת
# Intended (HE): עייף
# Similarity: 0.8116 — ✔️ KEEP
#
# ✔️ LOVING found via direct match: 'אוהב' in 'אוהב אותך כמו שאני עושה'
#
# ✔️ AFRAID found via direct match: 'מפחד' in 'אני מפחד'
#
# Word: love
# Original Sentence: send back my love
# Translated (HE): שלח בחזרה את אהבתי
# Intended (HE): אהבה
# Similarity: 0.8017 — ✔️ KEEP
#
# ✔️ SAD found via direct match: 'עצוב' in 'אין אף אחד לא יכול להיות כל כך עצוב'
#
# ✔️ DESPAIR found via direct match: 'ייאוש' in 'ומלא ייאוש'
#
# Word: lost
# Original Sentence: but i got lost a time or two
# Translated (HE): אבל הלכתי לאיבוד פעם או שתיים
# Intended (HE): אבוד
# Similarity: 0.7945 — ✔️ KEEP
#
# ✔️ LOVE found via direct match: 'אהבה' in 'בתקווה שאמצא אהבה אמיתית לאורך הדרך השבורה'
#
# ✔️ LOVING found via direct match: 'אוהב' in 'מכוון אותי בדרך לזרועותיך האוהבות'
#
# Word: hurt
# Original Sentence: all this hurt
# Translated (HE): כל זה כאב
# Intended (HE): פגוע
# Similarity: 0.8178 — ✔️ KEEP
#
# ✔️ SAFE found via direct match: 'בטוח' in 'תגיד לי שאני בטוח שאתה מקבל אותי עכשיו'
#
# Word: lost
# Original Sentence: i wont be lost forever
# Translated (HE): אני לא אבדה לנצח
# Intended (HE): אבוד
# Similarity: 0.8819 — ✔️ KEEP
#
# ✔️ ANGER found via direct match: 'כעס' in 'כעס אוהב בלבול'
#
# Word: love
# Original Sentence: anger love confusion
# Translated (HE): כעס אוהב בלבול
# Intended (HE): אהבה
# Similarity: 0.7587 — ✔️ KEEP
#
# Word: love
# Original Sentence: wish we never met wish i never let me love you
# Translated (HE): הלוואי שלעולם לא נפגשנו הלוואי שלעולם לא אתן לי לאהוב אותך
# Intended (HE): אהבה
# Similarity: 0.5963 — ❌ SKIP
#
# Word: hate
# Original Sentence: left without a sound i hate this
# Translated (HE): נותר בלי צליל אני שונא את זה
# Intended (HE): שנאה
# Similarity: 0.7133 — ❌ SKIP
#
# ✔️ HELPLESS found via direct match: 'חסר אונים' in 'להרגיש כל כך חסר אונים'
#
# ✔️ TIRED found via direct match: 'עייף' in 'חייב לאכול ואז אני כל כך עייף'
#
# ✔️ EMOTIONS found via direct match: 'רגשות' in 'מה יכול להיות עדיף לשלוח את הרגשות שלך לחג'
#
# ✔️ STRONG found via direct match: 'חזק' in 'תביא את זה על אני עייף אבל אני חזק'
#
# ✔️ CONFUSED found via direct match: 'מבולבל' in 'אני אבוד מבולבל im מחוץ למנגינה'
#
# ✔️ LOST found via direct match: 'אבוד' in 'אני אבוד מבולבל im מחוץ למנגינה'
#
# ✔️ HAND found via direct match: 'יד' in 'היא תיגע בך ביד עכשיו'
#
# Word: eyes
# Original Sentence: she will smile and ask you with her eyes to stay
# Translated (HE): היא תחייך ותבקש ממך בעיניה להישאר
# Intended (HE): עיניים
# Similarity: 0.8565 — ✔️ KEEP
#
# ✔️ HAIR found via direct match: 'שיער' in 'ראית את אור השמש שופך בשיערה'
#
# Word: mouth
# Original Sentence: and felt her warm mouth on ya in the summer air
# Translated (HE): והרגישה את פיה החם על כן באוויר הקיץ
# Intended (HE): פה
# Similarity: 0.6716 — ❌ SKIP
#
# Word: fearless
# Original Sentence: fearless
# Translated (HE): נוֹעָז
# Intended (HE): חסר פחד
# Similarity: 0.8574 — ✔️ KEEP
#
# ✔️ BRAVE found via direct match: 'אמיץ' in 'מפחד או אמיץ'
#
# Word: scared
# Original Sentence: scared or brave
# Translated (HE): מפחד או אמיץ
# Intended (HE): מפוחד
# Similarity: 0.9233 — ✔️ KEEP
#
# Word: candy
# Original Sentence: candy came from out on the island
# Translated (HE): סוכריות הגיעו מהאי
# Intended (HE): ממתק
# Similarity: 0.6804 — ❌ SKIP
#
# ✔️ SUGAR found via direct match: 'סוכר' in 'פיית שזיף סוכר באה ופגעה ברחובות'
#
# ✔️ PLUM found via direct match: 'שזיף' in 'פיית שזיף סוכר באה ופגעה ברחובות'
#
# Word: honey
# Original Sentence: said hey honey take a walk on the wild side
# Translated (HE): אמר היי מותק צא לטיול בצד הפראי
# Intended (HE): דבש
# Similarity: 0.6313 — ❌ SKIP
#
# ✔️ HEAD found via direct match: 'ראש' in 'אבל היא מעולם לא איבדה את ראשה'
#
# ✔️ EYEBROWS found via direct match: 'גבות' in 'מכה את גבותיה בדרך'
#
# Word: legs
# Original Sentence: shaved her legs and then he was a she
# Translated (HE): גילח את רגליה ואז הוא היה היא
# Intended (HE): רגליים
# Similarity: 0.7966 — ✔️ KEEP
#
# Word: mama
# Original Sentence: when the mama pajama rolled out a bed
# Translated (HE): כאשר הפיג'מה של אימא גלגלה מיטה
# Intended (HE): אמא
# Similarity: 0.6285 — ❌ SKIP
#
# ✔️ PAPA found via direct match: 'אבא' in 'כשהאבא גילה שהוא החל לצעוק'
#
# ✔️ HOUSE found via direct match: 'בית' in 'אני הולך לתקוע לו את בית המעצר'
#
# Word: love
# Original Sentence: baby girl id really love to see your face
# Translated (HE): תינוקת תינוקת ממש אוהבת לראות את הפנים שלך
# Intended (HE): אהבה
# Similarity: 0.6448 — ❌ SKIP
#
# Word: surprised
# Original Sentence: and dont be surprised if you catch me gazing gazing
# Translated (HE): ואל תתפלא אם תתפוס אותי מבט מבט
# Intended (HE): מופתע
# Similarity: 0.8507 — ✔️ KEEP
#
# ✔️ SEXY found via direct match: 'סקסי' in 'אתה סקסי ואתה יודע שזה יודע את זה יודע את זה'
#
# ✔️ EYES found via direct match: 'עיניים' in 'אה אני לא רוצה לעצום את העיניים'
#
# Word: toes
# Original Sentence: from your head to your toes
# Translated (HE): מהראש שלך עד בהונותיך
# Intended (HE): אצבעות רגליים
# Similarity: 0.9527 — ✔️ KEEP
#
# ✔️ HEAD found via direct match: 'ראש' in 'מהראש שלך עד בהונותיך'
#
# ✔️ LOVE found via direct match: 'אהבה' in 'נסגר מאהבה'
#
# ✔️ IN LOVE WITH found via direct match: 'מאוהב ב' in 'אני מאוהב בך'
#
# ✔️ LONELINESS found via direct match: 'בדידות' in 'עולם הבדידות'
#
# ✔️ DOUBT found via direct match: 'ספק' in 'נסה למלא אותי בספק'
#
# ✔️ AFRAID found via direct match: 'מפחד' in 'אבל אתה מפחד מכדי להתמודד עם השדים'
#
# ✔️ DOUBTS found via direct match: 'ספקות' in 'אבל ידעתי שתמיד היו לך הספקות שלך'
#
# Word: feeling
# Original Sentence: said how are you feeling when the king has gotta lie down
# Translated (HE): אמר איך אתה מרגיש כשהמלך צריך לשכב
# Intended (HE): תחושה
# Similarity: 0.7736 — ✔️ KEEP
#
# ✔️ LOVE found via direct match: 'אהבה' in 'האהבה היחידה שאתה רוצה תהיה שלי'
#
# ✔️ LONELINESS found via direct match: 'בדידות' in 'איכשהו אני צריך להניע את הבדידות הזו'
#
# ✔️ STRONG found via direct match: 'חזק' in 'אני חייב להיות חזק אני אמשיך'
#
# Word: love
# Original Sentence: cause they dont love you like i do
# Translated (HE): כי הם לא אוהבים אותך כמוני
# Intended (HE): אהבה
# Similarity: 0.6741 — ❌ SKIP
#
# Word: trust
# Original Sentence: trust me youre always on my mind
# Translated (HE): תאמין לי שאתה תמיד בראש שלי
# Intended (HE): אמון
# Similarity: 0.7555 — ✔️ KEEP
#
# ✔️ DOUBT found via direct match: 'ספק' in 'אני לא משאיל ספק'
#
# ✔️ LOVE found via direct match: 'אהבה' in 'האהבה שלי אליך כל כך חזקה'
#
# ✔️ HUNGRY found via direct match: 'רעב' in 'ראה את התינוק שלי כשאני רעב לאהבתך אתה מספק אותי'
#
# ✔️ STRONG found via direct match: 'חזק' in 'האהבה שלי אליך כל כך חזקה'
#
# ✔️ INSANE found via direct match: 'מטורף' in 'ילדה אתה יודע שזה יניע אותי מטורף'
#
# Word: safe
# Original Sentence: and as we lay here ill keep you safe ill keep you warm
# Translated (HE): וכששכבנו כאן אני אשמור עליכם אני אשמור עליכם לחמם
# Intended (HE): בטוח
# Similarity: 0.7223 — ❌ SKIP
#
# ✔️ STRONG found via direct match: 'חזק' in 'כמה זמן טוב לשמור על אהבה חזקה'
#
# ✔️ LOVING found via direct match: 'אוהב' in 'אוי מותק אני אהיה אוהב אותך'
#
# ✔️ LONELY found via direct match: 'בודד' in 'אני יהיה אדם בודד אדם משוגע אדם טוב יותר'
#
# Word: love
# Original Sentence: that is i love you and all the things that you stand for
# Translated (HE): זה אני אוהב אותך ואת כל הדברים שאתה עומד עליהם
# Intended (HE): אהבה
# Similarity: 0.7172 — ❌ SKIP
#
# Word: hurt
# Original Sentence: if youve been hurt before
# Translated (HE): אם נפגעת לפני כן
# Intended (HE): פגוע
# Similarity: 0.7850 — ✔️ KEEP
#
# Word: love
# Original Sentence: come share share my love
# Translated (HE): בוא שתף ​​שתף את אהבתי
# Intended (HE): אהבה
# Similarity: 0.7688 — ✔️ KEEP
#
# Word: lost
# Original Sentence: and the dream that a broken heart that lost
# Translated (HE): והחלום שלב שבור שאיבד
# Intended (HE): אבוד
# Similarity: 0.7923 — ✔️ KEEP
#
# ✔️ BROKEN HEART found via direct match: 'לב שבור' in 'והחלום שלב שבור שאיבד'
#
# ✔️ LOVE found via direct match: 'אהבה' in 'האהבה שלך חזקה כמו'
#
# ✔️ AFRAID found via direct match: 'מפחד' in 'והנה עומד האיש שהאיש מפחד מדי'
#
# Word: broken heart
# Original Sentence: it no use at all to my broken heart
# Translated (HE): זה בכלל לא מועיל ללב השבור שלי
# Intended (HE): לב שבור
# Similarity: 0.8204 — ✔️ KEEP
#
# ✔️ STRONG found via direct match: 'חזק' in 'האהבה שלך חזקה כמו'
#
# Word: trust
# Original Sentence: so put your trust in me
# Translated (HE): אז שים את אמונך בי
# Intended (HE): אמון
# Similarity: 0.9071 — ✔️ KEEP
#
# Word: afraid
# Original Sentence: dont be afraid
# Translated (HE): אל תפחד
# Intended (HE): מפחד
# Similarity: 0.8532 — ✔️ KEEP
#
# Word: satisfied
# Original Sentence: i can keep you satisfied
# Translated (HE): אני יכול לשמור אותך מרוצה
# Intended (HE): מסופק
# Similarity: 0.8072 — ✔️ KEEP
#
# Word: desire
# Original Sentence: if it love that you desire
# Translated (HE): אם זה אוהב שאתה רוצה
# Intended (HE): תשוקה
# Similarity: 0.8481 — ✔️ KEEP
#
# Word: love
# Original Sentence: ill give all of my love to you
# Translated (HE): אני אתן לך את כל אהבתי
# Intended (HE): אהבה
# Similarity: 0.8175 — ✔️ KEEP
#
# ✔️ SHY found via direct match: 'ביישן' in 'ואתה די ביישן'
#
# ✔️ HAND found via direct match: 'יד' in 'ביום ששמתי את ליבי ביד שלך'
#
# ✔️ EYES found via direct match: 'עיניים' in 'כל בוקר אתה קם ופוקח את העיניים'
#
# ✔️ NERVE found via direct match: 'עצב' in 'סוף סוף מצאתי את העצב לומר'
#
# Word: desire
# Original Sentence: what your desire cause ill light that fire
# Translated (HE): מה הרצון שלך גורם לאור חולה שאש
# Intended (HE): תשוקה
# Similarity: 0.7616 — ✔️ KEEP
#
# Word: love
# Original Sentence: girl i been longin to make love to you
# Translated (HE): ילדה הייתי ארוכה כדי להתאהב בך
# Intended (HE): אהבה
# Similarity: 0.7130 — ❌ SKIP
#
# ✔️ DOUBT found via direct match: 'ספק' in 'על זה להתעסק בזה תינוק ללא ספק'
#
# Word: desire
# Original Sentence: but my desire is taken over me
# Translated (HE): אבל הרצון שלי משתלט עליי
# Intended (HE): תשוקה
# Similarity: 0.7746 — ✔️ KEEP
#
# Word: love
# Original Sentence: on your love i can depend
# Translated (HE): על אהבתך אני יכול להיות תלוי
# Intended (HE): אהבה
# Similarity: 0.7465 — ❌ SKIP
#
# Word: feeling
# Original Sentence: still be feeling this way
# Translated (HE): עדיין מרגיש ככה
# Intended (HE): תחושה
# Similarity: 0.8459 — ✔️ KEEP
#
# Word: love
# Original Sentence: knowing you wanna fall in love and have a baby
# Translated (HE): בידיעה שאתה רוצה להתאהב ולהביא תינוק
# Intended (HE): אהבה
# Similarity: 0.6614 — ❌ SKIP
#
# ✔️ IN LOVE WITH found via direct match: 'מאוהב ב' in 'כי עכשיו אני מבין שאני מאוהב בך'
#
# ✔️ FALL IN LOVE found via direct match: 'להתאהב' in 'בידיעה שאתה רוצה להתאהב ולהביא תינוק'
#
# ✔️ LONELY found via direct match: 'בודד' in 'מצאתי את זה במקום הבודד הזה'
#
# Word: love
# Original Sentence: but i love you
# Translated (HE): אבל אני אוהב אותך
# Intended (HE): אהבה
# Similarity: 0.8465 — ✔️ KEEP
#
# Word: loved
# Original Sentence: it was honor that you loved me
# Translated (HE): זה היה כבוד שאהבת אותי
# Intended (HE): אהוב
# Similarity: 0.7580 — ✔️ KEEP
#
# ✔️ LOVING found via direct match: 'אוהב' in 'ואני אפילו לא יכול מישהו אחר שאוהב אותך'
#
# Word: tender
# Original Sentence: from my tender sentimental woes
# Translated (HE): מהצרות הסנטימנטליות הרכות שלי
# Intended (HE): עדין
# Similarity: 0.6804 — ❌ SKIP
#
# Word: sentimental
# Original Sentence: from my tender sentimental woes
# Translated (HE): מהצרות הסנטימנטליות הרכות שלי
# Intended (HE): רגשני
# Similarity: 0.6296 — ❌ SKIP
#
# ✔️ LOVE found via direct match: 'אהבה' in 'אוי איך שיר האהבה שלי בוכה בעדינות'
#
# Word: feet
# Original Sentence: my man lay beside me and my black dog at my feet
# Translated (HE): האיש שלי שכב לידי והכלב השחור שלי לרגלי
# Intended (HE): רגליים
# Similarity: 0.7585 — ✔️ KEEP
#
# Word: eyes
# Original Sentence: have you seen the black dog eyes starin in the fire
# Translated (HE): ראית את עיני הכלבים השחורים כוכבים באש
# Intended (HE): עיניים
# Similarity: 0.8537 — ✔️ KEEP
#
# Word: teeth
# Original Sentence: have you seen the black dog teeth sharp like a knife
# Translated (HE): ראית את שיני הכלב השחור חדות כמו סכין
# Intended (HE): שיניים
# Similarity: 0.8614 — ✔️ KEEP
#
# ✔️ THROAT found via direct match: 'גרון' in 'ראית אותו קורע גרון לקחת חיים'
#
# Word: feeling
# Original Sentence: and im feeling like one of your photographs girl
# Translated (HE): ואני מרגיש כמו אחת מצילומי הצילומים שלך
# Intended (HE): תחושה
# Similarity: 0.7570 — ✔️ KEEP
#
# ✔️ SADNESS found via direct match: 'עצב' in 'לגרום לעצב שעצוב מכדי להיות אמיתי'
#
# ✔️ SAD found via direct match: 'עצוב' in 'לגרום לעצב שעצוב מכדי להיות אמיתי'
#
# ✔️ PASSIONATE found via direct match: 'נלהב' in 'אז יש לך את כל הכינורות הנלהבים שלך'
#
# ✔️ LOVE found via direct match: 'אהבה' in 'כי אהבה היא בעיקר רק זיכרונות שאתה רואה'
#
# ✔️ HAND found via direct match: 'יד' in 'חייתי מיד לפה'
#
# ✔️ STOMACH found via direct match: 'בטן' in 'אתה מקשיב כאשר הבטן שלך מדברת'
#
# ✔️ MOUTH found via direct match: 'פה' in 'חייתי מיד לפה'
#
# ✔️ DOGS found via direct match: 'כלבים' in 'והכלבים אלוהים שלי הם רעבים כל הזמן'
#
# ✔️ SNAKES found via direct match: 'נחשים' in 'והנחשים ישנים במקום בו העשבים עבים'
#
# ✔️ GRASSHOPPER found via direct match: 'חגב' in 'ובעשבים העשבים המאובקים קופץ חגב ישן ושמן'
#
# ✔️ HUNGRY found via direct match: 'רעב' in 'והכלבים אלוהים שלי הם רעבים כל הזמן'
#
# Word: sick
# Original Sentence: the heavy sweetness like to make me sick
# Translated (HE): המתיקות הכבדה אוהבת לחלות אותי
# Intended (HE): חולה
# Similarity: 0.7493 — ❌ SKIP
#
# Word: angry
# Original Sentence: i think i feel an angry oven heat
# Translated (HE): אני חושב שאני מרגיש חום תנור זועם
# Intended (HE): כועס
# Similarity: 0.7481 — ❌ SKIP
#
# Word: road
# Original Sentence: i think i see a wagon rutted road
# Translated (HE): אני חושב שאני רואה עגלה דרך רוט
# Intended (HE): כביש
# Similarity: 0.7807 — ✔️ KEEP
#
# Word: tracks
# Original Sentence: with the weeds growing tall between the tracks
# Translated (HE): כשהעשבים שוטים גדלים בין המסילה
# Intended (HE): מסילות
# Similarity: 0.8664 — ✔️ KEEP
#
# ✔️ WAGON found via direct match: 'עגלה' in 'אני חושב שאני רואה עגלה דרך רוט'
#
# ✔️ GRANDPA found via direct match: 'סבא' in 'יום אחד חולה להיות סבא אפור זקן'
#
# ✔️ HOUSES found via direct match: 'בתים' in 'שם הבתים לא כולם זהים'
#
# ✔️ GRANDMA found via direct match: 'סבתא' in 'כל עוד תהיה סבתא הגדולה שלי'
#
# ✔️ DADDY found via direct match: 'אבא' in 'ואבא הלך למכולת'
#
# Word: mama
# Original Sentence: mama was rockin out on the front porch
# Translated (HE): אימא הייתה רוקין בחוץ על המרפסת הקדמית
# Intended (HE): אמא
# Similarity: 0.6439 — ❌ SKIP
#
# ✔️ BROTHER found via direct match: 'אח' in 'ואח עזב יום קודם'
#
# ✔️ SISTER found via direct match: 'אחות' in 'האחות הקטנה הייתה משחקת'
#
# ✔️ HOUSE found via direct match: 'בית' in 'היה הרבה אהבה בבית הישן ההוא'
#
# ✔️ CHILD found via direct match: 'ילד' in 'ניסיתי להיות גבר כשהייתי רק ילד'
#
# ✔️ COUSIN found via direct match: 'בן דוד' in 'הוא בן דוד לאדם בשם ג'ון'
#
# Word: kin
# Original Sentence: well he this little baby kin
# Translated (HE): ובכן הוא הקרוב הקטן הזה
# Intended (HE): קרובי משפחה
# Similarity: 0.9093 — ✔️ KEEP
#
# Word: baby
# Original Sentence: well he this little baby kin
# Translated (HE): ובכן הוא הקרוב הקטן הזה
# Intended (HE): תינוק
# Similarity: 0.7957 — ✔️ KEEP
#
# Word: shoulder
# Original Sentence: evil angel on my shoulder
# Translated (HE): מלאך מרושע על כתפי
# Intended (HE): כתף
# Similarity: 0.6719 — ❌ SKIP
#
# ✔️ EYES found via direct match: 'עיניים' in 'והסיגריה הראשונה הזו שרפה את העיניים שלך'
#
# ✔️ TONGUE found via direct match: 'לשון' in 'ובכן הלגימה הראשונה של הוויסקי שרפה את הלשון שלך'
#
# Word: love
# Original Sentence: o and if youre going to love me
# Translated (HE): הו ואם אתה הולך לאהוב אותי
# Intended (HE): אהבה
# Similarity: 0.7359 — ❌ SKIP
#
# ✔️ QUIET found via direct match: 'שקט' in 'GEE הכיסים שלי שקט אדיר'
#
# Word: trust
# Original Sentence: taking trust returning pain
# Translated (HE): נטילת כאב חוזר
# Intended (HE): אמון
# Similarity: 0.7595 — ✔️ KEEP
#
# Word: sail
# Original Sentence: a ship is under sail
# Translated (HE): ספינה נמצאת תחת מפרש
# Intended (HE): להפליג
# Similarity: 0.8598 — ✔️ KEEP
#
# Word: harbor
# Original Sentence: just out in the harbor
# Translated (HE): פשוט בחוץ בנמל
# Intended (HE): מעגן
# Similarity: 0.7826 — ✔️ KEEP
#
# ✔️ SHIPS found via direct match: 'ספינות' in 'כל הספינות ישנות'
#
# ✔️ SHIP found via direct match: 'ספינה' in 'ספינה נמצאת תחת מפרש'
#
# Word: hurt
# Original Sentence: but every time you hurt me i grow a little stronger
# Translated (HE): אבל בכל פעם שפגעי בי אני מתחזק קצת יותר
# Intended (HE): פגוע
# Similarity: 0.7043 — ❌ SKIP
#
# Word: love
# Original Sentence: just cause im in love with you
# Translated (HE): פשוט כי אני מאוהב בך
# Intended (HE): אהבה
# Similarity: 0.7116 — ❌ SKIP
#
# ✔️ IN LOVE WITH found via direct match: 'מאוהב ב' in 'פשוט כי אני מאוהב בך'
#
# ✔️ STRONG found via direct match: 'חזק' in 'חולה בקרוב יהיה חזק מספיק כדי להיפרד'
#
# ✔️ MAMA found via direct match: 'אמא' in 'תגיד אמא להן בנות לא יפות כמוך'
#
# ✔️ CHILD found via direct match: 'ילד' in 'אלביס היה תמיד ילד צייתני'
#
# ✔️ DADDY found via direct match: 'אבא' in 'תסתכל על אבא שלה שהיא בדיוק כמו חדשה'
#
# Word: trust
# Original Sentence: and to trust somebody
# Translated (HE): ולסמוך על מישהו
# Intended (HE): אמון
# Similarity: 0.7760 — ✔️ KEEP
#
# ✔️ STRONG found via direct match: 'חזק' in 'זה מה שעושה אותך חזק'
#
# Word: kind
# Original Sentence: but if youre the trusting kind
# Translated (HE): אבל אם אתה מהסוג האמון
# Intended (HE): אדיב
# Similarity: 0.8541 — ✔️ KEEP
#
# Word: trusting
# Original Sentence: but if youre the trusting kind
# Translated (HE): אבל אם אתה מהסוג האמון
# Intended (HE): בוטח
# Similarity: 0.7983 — ✔️ KEEP
#
# Word: disappointed
# Original Sentence: is to be disappointed
# Translated (HE): זה להתאכזב
# Intended (HE): מאוכזב
# Similarity: 0.8934 — ✔️ KEEP
#
# Word: love
# Original Sentence: if you love somebody
# Translated (HE): אם אתה אוהב מישהו
# Intended (HE): אהבה
# Similarity: 0.8589 — ✔️ KEEP
#
# ✔️ HAND found via direct match: 'יד' in 'זה הביא לנו ידיים רועדות ועיניים כושלות'
#
# ✔️ EYES found via direct match: 'עיניים' in 'זה הביא לנו ידיים רועדות ועיניים כושלות'
#
# ✔️ HANDS found via direct match: 'ידיים' in 'זה הביא לנו ידיים רועדות ועיניים כושלות'
#
# Word: travel
# Original Sentence: oh when it comes your times to travel likewise dont feel lost
# Translated (HE): אה כשזה נובע הזמנים שלך לנסוע כמו כן אל תרגיש אבוד
# Intended (HE): נסיעה
# Similarity: 0.7402 — ❌ SKIP
#
# Word: fare
# Original Sentence: through this life weve labored hard to earn our meager fare
# Translated (HE): דרך החיים האלה עבדו קשה להרוויח את מחיר הנסיעה שלנו
# Intended (HE): דמי נסיעה
# Similarity: 0.8463 — ✔️ KEEP
#
# ✔️ JOURNEY found via direct match: 'מסע' in 'יש לי עוד מסע על דעתי'
#
# ✔️ SKIN found via direct match: 'עור' in 'מילות אישה נכשלות בי העור שלך מתוק וחם'
#
# Word: lips
# Original Sentence: oh girl any moment i may kiss your lips
# Translated (HE): אוי ילדה בכל רגע שאנשק את שפתייך
# Intended (HE): שפתיים
# Similarity: 0.8450 — ✔️ KEEP
#
# ✔️ ARMS found via direct match: 'זרועות' in 'אני רוצה לנחם אותך ולהחזיק אותך בזרועותיי'
#
# ✔️ HURT found via direct match: 'פגוע' in 'אבל יתכן שתצטרך לפגוע בי לפני שאראה את האור'
#
# ✔️ STRONG found via direct match: 'חזק' in 'ולמרות ששמעתי שאתה מתקשר אני פשוט לא מספיק חזק'
#
# ✔️ TIRED OF found via direct match: 'נמאס' in 'נמאס לך על סטראלין כל יום'
#
# ✔️ DESIRE found via direct match: 'תשוקה' in 'קשר את ידי כשאני מושיט את התשוקה'
#
# Word: love
# Original Sentence: when all i had to do was surrender to your love
# Translated (HE): כאשר כל מה שהייתי צריך לעשות זה להיכנע לאהבתך
# Intended (HE): אהבה
# Similarity: 0.6372 — ❌ SKIP
#
# Word: knees
# Original Sentence: i know that others fall down on their knees for mercy
# Translated (HE): אני יודע שאחרים נופלים על ברכיהם לרחמים
# Intended (HE): ברכיים
# Similarity: 0.8486 — ✔️ KEEP
#
# Word: eyes
# Original Sentence: wont you blind my eyes when all i see is temptation
# Translated (HE): לא תענוור את עיניי כשכל מה שאני רואה זה פיתוי
# Intended (HE): עיניים
# Similarity: 0.8568 — ✔️ KEEP
#
# Word: hands
# Original Sentence: an tie my hands when i reach out with desire
# Translated (HE): קשר את ידי כשאני מושיט את התשוקה
# Intended (HE): ידיים
# Similarity: 0.7923 — ✔️ KEEP
#
# Word: knees
# Original Sentence: gunna wade into my knees
# Translated (HE): גוננה משוטטת בברכי
# Intended (HE): ברכיים
# Similarity: 0.8852 — ✔️ KEEP
#
# ✔️ FEET found via direct match: 'רגליים' in 'רגליים חשופות על אדמה דרומית'
#
# ✔️ EYES found via direct match: 'עיניים' in 'אני יכול לעצום את העיניים כשאני רוצה לחזור'
#
# Word: love
# Original Sentence: cause people like to talk lord how they love to talk
# Translated (HE): לגרום לאנשים אוהבים לדבר אדוני איך הם אוהבים לדבר
# Intended (HE): אהבה
# Similarity: 0.6269 — ❌ SKIP
#
# Word: tired
# Original Sentence: she never too far away or too tired to say i want you
# Translated (HE): היא אף פעם לא רחוקה מדי או עייפה מדי לומר שאני רוצה אותך
# Intended (HE): עייף
# Similarity: 0.7168 — ❌ SKIP
#
# ✔️ PROUD found via direct match: 'גאה' in 'התינוק שלי גורם לי לורד גאה לא תגרום לי להיות גאה'
#
# Word: loved
# Original Sentence: it all because i loved you because i held you because i believed you
# Translated (HE): הכל בגלל שאהבתי אותך כי החזקתי אותך כי האמנתי לך
# Intended (HE): אהוב
# Similarity: 0.6888 — ❌ SKIP
#
# ✔️ HURTING found via direct match: 'כואב' in 'קבל סיכוי נוסף שכואב לי שנשברתי'
#
# Word: loving
# Original Sentence: i made a mistake of loving you
# Translated (HE): טעיתי לאהוב אותך
# Intended (HE): אוהב
# Similarity: 0.7677 — ✔️ KEEP
#
# ✔️ LOVE found via direct match: 'אהבה' in 'האהבה הזו נגמרה אז מותק פשוט תן לזה לשרוף'
#
# ✔️ SAD found via direct match: 'עצוב' in 'הפעולות שלך עומדות להשאיר אותך עצוב ובודד'
#
# ✔️ LONELY found via direct match: 'בודד' in 'הפעולות שלך עומדות להשאיר אותך עצוב ובודד'
#
# ✔️ SEXY found via direct match: 'סקסי' in 'קראת לי סקסי כשהתחלנו לראשונה'
#
# ✔️ LOVE found via direct match: 'אהבה' in 'אהבה פירושה ללמוד לשחרר אותי'
#
# Word: sick
# Original Sentence: and im tired of it sick and tired of it
# Translated (HE): ונמאס לי שזה נמאס מזה
# Intended (HE): חולה
# Similarity: 0.7749 — ✔️ KEEP
#
# ✔️ TIRED OF found via direct match: 'נמאס' in 'ונמאס לי שזה נמאס מזה'
#
# Word: love
# Original Sentence: im gonna love you love you love you like like im from overseas
# Translated (HE): אני הולך לאהוב אותך אוהב אותך אוהב אותך כמו שאני מעבר לים
# Intended (HE): אהבה
# Similarity: 0.6694 — ❌ SKIP
#
# ✔️ BORING found via direct match: 'משעמם' in 'עכשיו אתה יודע שנוכל פשוט להחליף מספרים אבל אז זה משעמם'
#
# ✔️ COMFORTABLE found via direct match: 'נוח' in 'הגוף שלך פלוס הגוף שלי אומר שמישהו ירגיש בנוח'
#
# Word: love
# Original Sentence: to be in love alone
# Translated (HE): להיות מאוהב לבד
# Intended (HE): אהבה
# Similarity: 0.7082 — ❌ SKIP
#
# Word: hurting
# Original Sentence: cause you cant keep on hurting me
# Translated (HE): כי אתה לא יכול להמשיך לפגוע בי
# Intended (HE): כואב
# Similarity: 0.7401 — ❌ SKIP
#
# Word: doubt
# Original Sentence: trying not to doubt us
# Translated (HE): מנסה לא לפקפק בנו
# Intended (HE): ספק
# Similarity: 0.6113 — ❌ SKIP
#
# ✔️ LOST found via direct match: 'אבוד' in 'כל כך מבולבל שאני כל כך אבוד'
#
# ✔️ LOVE found via direct match: 'אהבה' in 'אהבה זו מחוץ לשליטה'
#
# ✔️ CONFUSED found via direct match: 'מבולבל' in 'כל כך מבולבל שאני כל כך אבוד'
#
# ✔️ INSECURE found via direct match: 'חסר ביטחון' in 'אתה גורם לי להיות חסר ביטחון'
#
# Word: tired
# Original Sentence: that love thing i tried it over and over til i got tired
# Translated (HE): את דבר האהבה הזה שניסיתי את זה שוב ושוב עד עייפתי
# Intended (HE): עייף
# Similarity: 0.7459 — ❌ SKIP
#
# Word: kind
# Original Sentence: it that kind of love it that kind of love
# Translated (HE): זה סוג של אוהב את זה סוג כזה של אהבה
# Intended (HE): אדיב
# Similarity: 0.7945 — ✔️ KEEP
#
# Word: lost
# Original Sentence: and id be crazy if i ever lost you
# Translated (HE): ותזהה משוגע אם איבדתי אותך אי פעם
# Intended (HE): אבוד
# Similarity: 0.8222 — ✔️ KEEP
#
# ✔️ BROKEN HEART found via direct match: 'לב שבור' in 'התרגל להיות לבד שאני מסתיר את הכאב של לב שבור'
#
# ✔️ LOVE found via direct match: 'אהבה' in 'זה סוג של אוהב את זה סוג כזה של אהבה'
#
# ✔️ LOVE found via direct match: 'אהבה' in 'אני מרגיש שאני מרגיש את האהבה שלך'
#
# Word: kind
# Original Sentence: that kind of feelin you just soar
# Translated (HE): סוג כזה של תחושה שאתה פשוט ממריץ
# Intended (HE): אדיב
# Similarity: 0.7542 — ✔️ KEEP
#
# Word: feeling
# Original Sentence: im feeling im feeling your love
# Translated (HE): אני מרגיש שאני מרגיש את האהבה שלך
# Intended (HE): תחושה
# Similarity: 0.7808 — ✔️ KEEP
#
# Word: hate
# Original Sentence: hate to tell you youll be traveling alone
# Translated (HE): שונא להגיד לך שתטייל לבד
# Intended (HE): שנאה
# Similarity: 0.7084 — ❌ SKIP
#
# Word: unhappy
# Original Sentence: then be unhappy with two forever
# Translated (HE): ואז להיות לא מרוצה משניים לנצח
# Intended (HE): לא שמח
# Similarity: 0.7318 — ❌ SKIP
#
# Word: trust
# Original Sentence: we gonna party trust me im ok
# Translated (HE): אנחנו הולכים לחגוג תאמין לי שאני בסדר
# Intended (HE): אמון
# Similarity: 0.7232 — ❌ SKIP
#
# ✔️ LOVE found via direct match: 'אהבה' in 'למה אתה לא יכול לראות שאין לא בסדר באהבה אין סודות בינינו'
#
# Word: sad
# Original Sentence: that makes me sad i aint mad
# Translated (HE): זה מעציב אותי אני לא משוגע
# Intended (HE): עצוב
# Similarity: 0.7620 — ✔️ KEEP
#
# ✔️ TRUST found via direct match: 'אמון' in 'ואני רק רוצה לדון בדבר הזה שאנחנו מכנים אמון'
#
# Word: hurt
# Original Sentence: i was hurt but my heart is still beating
# Translated (HE): נפגעתי אבל הלב שלי עדיין פועם
# Intended (HE): פגוע
# Similarity: 0.7205 — ❌ SKIP
#
# ✔️ LOVE found via direct match: 'אהבה' in 'כל השמחה והכאב האהבה ושברון הלב'
#
# ✔️ AFRAID found via direct match: 'מפחד' in 'אולי אם אני מפחד להיכשל'
#
# Word: running
# Original Sentence: somewhere along the way were all running in a crazy race
# Translated (HE): איפשהו לאורך הדרך כולם רצו במירוץ מטורף
# Intended (HE): ריצה
# Similarity: 0.6279 — ❌ SKIP
#
# Word: win
# Original Sentence: the more you win the more you want
# Translated (HE): ככל שתנצח יותר אתה רוצה
# Intended (HE): לנצח
# Similarity: 0.7484 — ❌ SKIP
#
# Word: race
# Original Sentence: somewhere along the way were all running in a crazy race
# Translated (HE): איפשהו לאורך הדרך כולם רצו במירוץ מטורף
# Intended (HE): מרוץ
# Similarity: 0.7690 — ✔️ KEEP
#
# Word: sentimental
# Original Sentence: oh who needs that sentimental bullshit anyway
# Translated (HE): אוי מי בכל מקרה צריך את הבולשיט הסנטימנטלי הזה
# Intended (HE): רגשני
# Similarity: 0.6075 — ❌ SKIP
#
# Word: falling in love
# Original Sentence: and there a girl she falling in love near where the pianola stands
# Translated (HE): ושם ילדה שהיא מתאהבת ליד המקום בו פסנתולה עומדת
# Intended (HE): להתאהב
# Similarity: 0.7585 — ✔️ KEEP
#
# ✔️ FEELING found via direct match: 'תחושה' in 'ואני לא יכול להפסיק את התחושה השכחה מזמן כל כך ממנו'
#
# Word: weary
# Original Sentence: and oh the flame trees will blind the weary driver
# Translated (HE): ואוי עצי הלהבה יעוור את הנהג העייף
# Intended (HE): יגע
# Similarity: 0.5869 — ❌ SKIP
#
# ✔️ HURT found via direct match: 'פגוע' in 'לאהוב יכול לפגוע'
#
# ✔️ LOVE found via direct match: 'אהבה' in 'אנו שומרים על האהבה הזו בתצלום'
#
# Word: loving
# Original Sentence: loving can hurt
# Translated (HE): לאהוב יכול לפגוע
# Intended (HE): אוהב
# Similarity: 0.7563 — ✔️ KEEP
#
# Word: lost
# Original Sentence: and i didnt know i was lost
# Translated (HE): ולא ידעתי שאבדתי
# Intended (HE): אבוד
# Similarity: 0.8017 — ✔️ KEEP
#
# ✔️ LOVE found via direct match: 'אהבה' in 'ואהבה היא הפרס'
#
# ✔️ AFRAID found via direct match: 'מפחד' in 'לא מפחד לעצום את עיניי'
#
# Word: feeling
# Original Sentence: feeling my way through the darkness
# Translated (HE): מרגיש את דרכי בחושך
# Intended (HE): תחושה
# Similarity: 0.8157 — ✔️ KEEP
#
# Word: love
# Original Sentence: love you baby
# Translated (HE): אוהב אותך מותק
# Intended (HE): אהבה
# Similarity: 0.8224 — ✔️ KEEP
#
# Word: kind
# Original Sentence: everybody tells me he a kind guy
# Translated (HE): כולם אומרים לי שהוא בחור טוב לב
# Intended (HE): אדיב
# Similarity: 0.7258 — ❌ SKIP
#
# ✔️ LONELY found via direct match: 'בודד' in 'שחרר אותי עכשיו הילד הבודד שלי'
#
# Word: love
# Original Sentence: he feels me with his love
# Translated (HE): הוא מרגיש אותי עם אהבתו
# Intended (HE): אהבה
# Similarity: 0.7335 — ❌ SKIP
#
# Word: scared
# Original Sentence: im feeling real scared
# Translated (HE): אני מרגיש מפחד ממש
# Intended (HE): מפוחד
# Similarity: 0.8647 — ✔️ KEEP
#
# Word: feeling
# Original Sentence: one day i was in my room and i wasnt feeling you
# Translated (HE): יום אחד הייתי בחדר שלי ולא הרגשתי אותך
# Intended (HE): תחושה
# Similarity: 0.7717 — ✔️ KEEP
#
# ✔️ LOST found via direct match: 'אבוד' in 'כשהייתי אבוד'
#
# ✔️ SAFE found via direct match: 'בטוח' in 'הו תוביל אותי בטוח לנחיתה'
#
# ✔️ HUNGRY found via direct match: 'רעב' in 'של חיים חסרי חבר רעבים'
#
# ✔️ ARMS found via direct match: 'זרועות' in 'כל כך הרבה אהבה בתוך הזרועות האלה'
#
# Word: eyes
# Original Sentence: and i can see our future in your eyes
# Translated (HE): ואני יכול לראות את העתיד שלנו בעיניך
# Intended (HE): עיניים
# Similarity: 0.8627 — ✔️ KEEP
#
# ✔️ HAND found via direct match: 'יד' in 'הישאר איתי קח את היד שלי'
#
# Word: love
# Original Sentence: fall fall in love
# Translated (HE): סתיו מתאהב
# Intended (HE): אהבה
# Similarity: 0.7513 — ✔️ KEEP
#
# ✔️ SURPRISED found via direct match: 'מופתע' in 'ואני לא אהיה מופתע'
#
# Word: fall in love
# Original Sentence: fall fall in love
# Translated (HE): סתיו מתאהב
# Intended (HE): להתאהב
# Similarity: 0.8861 — ✔️ KEEP
#
# Word: loving
# Original Sentence: if loving was wrong
# Translated (HE): אם האהבה טעה
# Intended (HE): אוהב
# Similarity: 0.9120 — ✔️ KEEP
#
# ✔️ SHIP found via direct match: 'ספינה' in 'הספינה לא מפליגה'
#
# Word: sail
# Original Sentence: the ship doesnt sail
# Translated (HE): הספינה לא מפליגה
# Intended (HE): להפליג
# Similarity: 0.8927 — ✔️ KEEP
#
# Word: road
# Original Sentence: and when the road up ahead
# Translated (HE): וכאשר הדרך קדימה
# Intended (HE): כביש
# Similarity: 0.8342 — ✔️ KEEP
#
# Word: feeling
# Original Sentence: youre gonna know all that im feeling on the inside
# Translated (HE): אתה תדע את כל מה שאני מרגיש מבפנים
# Intended (HE): תחושה
# Similarity: 0.8084 — ✔️ KEEP
#
# ✔️ STRONG found via direct match: 'חזק' in 'זה לא על מי חלש או חזק'
#
# Word: sad
# Original Sentence: im not telling you all of this to make you sad
# Translated (HE): אני לא אומר לך את כל זה שיעצב אותך
# Intended (HE): עצוב
# Similarity: 0.7390 — ❌ SKIP
#
# Word: kind
# Original Sentence: im not the kind of girl to sit out on sidelines
# Translated (HE): אני לא מסוג הילדה לשבת על הקווים
# Intended (HE): אדיב
# Similarity: 0.7561 — ✔️ KEEP
#
# Word: unhappy
# Original Sentence: im unhappy so if you love me
# Translated (HE): אני לא מרוצה אז אם אתה אוהב אותי
# Intended (HE): לא שמח
# Similarity: 0.6996 — ❌ SKIP
#
# ✔️ LOVE found via direct match: 'אהבה' in 'אני צריך את האהבה שלך'
#
# ✔️ LOVE found via direct match: 'אהבה' in 'אהבה בלתי פוסקת בלתי מוגבלת אשר'
#
# ✔️ SORROW found via direct match: 'צער' in 'בריכות צער גלי שמחה'
#
# Word: restless
# Original Sentence: restless wind inside a letter box
# Translated (HE): רוח חסרת מנוחה בתוך תיבת אותיות
# Intended (HE): חסר מנוחה
# Similarity: 0.8766 — ✔️ KEEP
#
# ✔️ CHILD found via direct match: 'ילד' in 'הילד הזה שסיפקת'
#
# Word: baby
# Original Sentence: that your baby boy will save our sons and daughters
# Translated (HE): שהילד שלך יציל את בנינו ובנותינו
# Intended (HE): תינוק
# Similarity: 0.8184 — ✔️ KEEP
#
# ✔️ DAUGHTERS found via direct match: 'בנות' in 'שהילד שלך יציל את בנינו ובנותינו'
#
# Word: scared
# Original Sentence: i feel young broken so so scared
# Translated (HE): אני מרגיש צעיר שבור כל כך מפחד
# Intended (HE): מפוחד
# Similarity: 0.8429 — ✔️ KEEP
#
# ✔️ SICK found via direct match: 'חולה' in 'אני בוכה מרגיש חולה של ליבי פועם פועם בשליטה'
#
# ✔️ STRONG found via direct match: 'חזק' in 'אני מצמצם את אגרופי ומנסה להישאר חזק'
#
# Word: eyes
# Original Sentence: close my eyes to see in the dark
# Translated (HE): עצום את עיניי לראות בחושך
# Intended (HE): עיניים
# Similarity: 0.8953 — ✔️ KEEP
#
# ✔️ HAIR found via direct match: 'שיער' in 'אני רוצה להרגיש את הגוף שלי שוב מרגיש את הרוח בשיער שלי כן'
#
# ✔️ HEAD found via direct match: 'ראש' in 'הטה את ראשי לאחור מרגיש שהדמעות נופלות'
#
# Word: love
# Original Sentence: ive got a track and id love you to take it
# Translated (HE): יש לי מסלול ואני אוהב אותך לקחת את זה
# Intended (HE): אהבה
# Similarity: 0.7592 — ✔️ KEEP
#
# Word: hate
# Original Sentence: let the haters hate
# Translated (HE): תן לשונאים לשנוא
# Intended (HE): שנאה
# Similarity: 0.6725 — ❌ SKIP
#
# ✔️ PROUD found via direct match: 'גאה' in 'הולה אני גאה בך'
#
# ✔️ SKIN found via direct match: 'עור' in 'עם עור ירוק אתה לא מתאים לקהל הזה'
#
# ✔️ HAIR found via direct match: 'שיער' in 'אוי הם משכו את השיער שלי הם הסירו את הכיסא שלי'
#
# ✔️ TEETH found via direct match: 'שיניים' in 'יש לך שיניים בדיוק כמו באגס באני'
#
# ✔️ LOVE found via direct match: 'אהבה' in 'לעזאזל האהבה הזו הדוקה בעור'
#
# Word: feeling
# Original Sentence: im feeling sexy and free
# Translated (HE): אני מרגיש סקסי וחופשי
# Intended (HE): תחושה
# Similarity: 0.7940 — ✔️ KEEP
#
# ✔️ SEXY found via direct match: 'סקסי' in 'אני מרגיש סקסי וחופשי'
#
# ✔️ TIRED found via direct match: 'עייף' in 'האם אני היחיד שמתעייף'
#
# Word: feeling
# Original Sentence: guarantee well be feeling alright
# Translated (HE): מתחייב היטב להרגיש בסדר
# Intended (HE): תחושה
# Similarity: 0.7278 — ❌ SKIP
#
# ✔️ MYSTERIOUS found via direct match: 'מסתורי' in 'מתנהג כל כך מסתורי ארור'
#
# ✔️ HAPPINESS found via direct match: 'אושר' in 'כסף לא יכול לקנות לנו אושר'
#
# ✔️ OBSESSED found via direct match: 'אובססיבי' in 'מדוע כולם כל כך אובססיביים'
#
# ✔️ LOVE found via direct match: 'אהבה' in 'שילמו באהבה הלילה'
#
# ✔️ FEET found via direct match: 'רגליים' in 'אז אנחנו נמשיך לכולם להזיז את הרגליים שלהם'
#
# ✔️ EYES found via direct match: 'עיניים' in 'יש לך גוונים על העיניים שלך'
#
# ✔️ HEAD found via direct match: 'ראש' in 'איש קוקוס ראש ירח ואפונה'
#
# ✔️ SKIN found via direct match: 'עור' in 'עור על עור'
#
# Word: feet
# Original Sentence: till our feet dont touch the floor oh oh oh
# Translated (HE): עד שרגלינו לא נוגעות ברצפה אוי אוי
# Intended (HE): רגליים
# Similarity: 0.7687 — ✔️ KEEP
#
# ✔️ BLOOD found via direct match: 'דם' in 'אני מרגיש שהדם ממהר לי בראש'
#
# ✔️ HEAD found via direct match: 'ראש' in 'אני מרגיש שהדם ממהר לי בראש'
#
# Word: lips
# Original Sentence: our arms pressing our lips kissing
# Translated (HE): זרועותינו לוחצות את שפתינו מתנשקות
# Intended (HE): שפתיים
# Similarity: 0.8066 — ✔️ KEEP
#
# ✔️ ARMS found via direct match: 'זרועות' in 'זרועותינו לוחצות את שפתינו מתנשקות'
#
# Word: feeling
# Original Sentence: what im feeling yeah
# Translated (HE): מה אני מרגיש כן
# Intended (HE): תחושה
# Similarity: 0.8455 — ✔️ KEEP
#
# Word: scared
# Original Sentence: im scared to know
# Translated (HE): אני מפחד לדעת
# Intended (HE): מפוחד
# Similarity: 0.9021 — ✔️ KEEP
#
# Word: lost
# Original Sentence: youre lost im found
# Translated (HE): אתה איבד את ה- IM
# Intended (HE): אבוד
# Similarity: 0.9121 — ✔️ KEEP
#
# ✔️ BORED found via direct match: 'משועמם' in 'האם אתה משועמם'
#
# ✔️ LOVE found via direct match: 'אהבה' in 'האם זו אהבה אתה יכול להגיד לי'
#
# ✔️ HURT found via direct match: 'פגוע' in 'הלוואי שיכולתי לפגוע בך בחזרה'
#
# Word: love
# Original Sentence: cause im sick for your love
# Translated (HE): כי אני חולה על אהבתך
# Intended (HE): אהבה
# Similarity: 0.7702 — ✔️ KEEP
#
# ✔️ SICK found via direct match: 'חולה' in 'כי אני חולה על אהבתך'
#
# Word: trust
# Original Sentence: im the bad guy cause i cant learn to trust
# Translated (HE): אני הבחור הרע כי אני לא יכול ללמוד לסמוך
# Intended (HE): אמון
# Similarity: 0.7517 — ✔️ KEEP
#
# ✔️ KNEES found via direct match: 'ברכיים' in 'ילדה על הברכיים'
#
# ✔️ HAIR found via direct match: 'שיער' in 'ילדה קושרים את השיער שלך אם אתה רוצה להיות כוכב'
#
# ✔️ LEGS found via direct match: 'רגליים' in 'כמה ייקח לך לפרוש את הרגליים האלה'
#
# Word: desire
# Original Sentence: youre my desire
# Translated (HE): אתה הרצון שלי
# Intended (HE): תשוקה
# Similarity: 0.8645 — ✔️ KEEP
#
# Word: love
# Original Sentence: love me like we used to know
# Translated (HE): אוהב אותי כמו פעם לדעת
# Intended (HE): אהבה
# Similarity: 0.7796 — ✔️ KEEP
#
# Word: feeling
# Original Sentence: am i feeling now
# Translated (HE): האם אני מרגיש עכשיו
# Intended (HE): תחושה
# Similarity: 0.8339 — ✔️ KEEP
#
# Word: hate
# Original Sentence: ok just a bit i hate to admit
# Translated (HE): אוקי רק קצת אני שונא להודות
# Intended (HE): שנאה
# Similarity: 0.7016 — ❌ SKIP
#
# ✔️ AFRAID found via direct match: 'מפחד' in 'אני פחות מפחד מהחושך'
#
# Word: kind
# Original Sentence: oh kind of sometimes maybe
# Translated (HE): אה סוג של לפעמים אולי
# Intended (HE): אדיב
# Similarity: 0.8638 — ✔️ KEEP
#
# Word: lost
# Original Sentence: but you came and you lost
# Translated (HE): אבל באת והפסדת
# Intended (HE): אבוד
# Similarity: 0.9010 — ✔️ KEEP
#
# ✔️ LONELY found via direct match: 'בודד' in 'האם אני בכלל מתבודד'
#
# ✔️ BLOOD found via direct match: 'דם' in 'כמו דם דרך הוורידים שלי'
#
# ✔️ BONES found via direct match: 'עצמות' in 'רוצה להרגיש תשוקה זורמת לעצמות שלי'
#
# ✔️ VEINS found via direct match: 'ורידים' in 'כמו דם דרך הוורידים שלי'
#
# Word: feeling
# Original Sentence: feeling weaker and weaker
# Translated (HE): מרגיש חלש וחלש יותר
# Intended (HE): תחושה
# Similarity: 0.8389 — ✔️ KEEP
#
# ✔️ STRONG found via direct match: 'חזק' in 'למה לחזק את זה לשבור את זה שוב'
#
# ✔️ CALM found via direct match: 'רגוע' in 'להרגיש את רוחי רגועה'
#
# Word: love
# Original Sentence: and id love to say i do
# Translated (HE): וזה אוהב לומר שאני כן
# Intended (HE): אהבה
# Similarity: 0.7509 — ✔️ KEEP
#
# ✔️ PROUD found via direct match: 'גאה' in 'אם אני גאה אולי עלי להסביר'
#
# ✔️ SHY found via direct match: 'ביישן' in 'ברגע שננשך פעמיים ביישן'
#
# ✔️ CAT found via direct match: 'חתול' in 'בזמן שאני מפנה את החתול שלי לגב'
#
# ✔️ BEE found via direct match: 'דבורה' in 'הבחור רוצח דבורה פראי'
#
# ✔️ SHARKS found via direct match: 'כרישים' in 'וצפה בהם כרישים שנושכים'
#
# Word: lost
# Original Sentence: they say lost boyz be a gang
# Translated (HE): הם אומרים שאבדו בויז להיות כנופיה
# Intended (HE): אבוד
# Similarity: 0.7445 — ❌ SKIP
#
# Word: love
# Original Sentence: aiyo why i love my mama
# Translated (HE): AIYO למה אני אוהבת את אמא שלי
# Intended (HE): אהבה
# Similarity: 0.7404 — ❌ SKIP
#
# ✔️ SAFE found via direct match: 'בטוח' in 'הבטוח שלי ויו אין לי שום דבר'
#
# Word: strike
# Original Sentence: cuz i get a strike just the right touch
# Translated (HE): כי אני מקבל שביתה בדיוק את המגע הנכון
# Intended (HE): להכות
# Similarity: 0.7610 — ✔️ KEEP
#
# Word: track
# Original Sentence: on this track i get spelming
# Translated (HE): במסלול הזה אני מקבל
# Intended (HE): מסילה
# Similarity: 0.8708 — ✔️ KEEP
#
# Word: throw
# Original Sentence: throw ya l in the sky if you feelin that
# Translated (HE): זרוק אותך לשמיים אם אתה מרגיש את זה
# Intended (HE): זריקה
# Similarity: 0.8270 — ✔️ KEEP
#
# Word: team
# Original Sentence: me and my team well gettin ya gut
# Translated (HE): אני והצוות שלי היטב מקבלים את הבטן
# Intended (HE): קבוצה
# Similarity: 0.7508 — ✔️ KEEP
#
# ✔️ BALL found via direct match: 'כדור' in 'ככה אנחנו עושים משחקים ושחור בכדור'
#
# ✔️ CREW found via direct match: 'צוות' in 'אני מייצג את הצוות שלי'
#
# Word: love
# Original Sentence: never met you but how i love you so
# Translated (HE): מעולם לא פגש אותך אבל איך אני אוהב אותך כל כך
# Intended (HE): אהבה
# Similarity: 0.7141 — ❌ SKIP
#
# ✔️ DESPERATE found via direct match: 'נואש' in 'אלה סימנים נואשים של זמנים נואשים'
#
# ✔️ DESPERATION found via direct match: 'ייאוש' in 'אז תגיד שלום לילדת הייאוש'
# Translation failed (attempt 1): The read operation timed out
#
# Word: afraid
# Original Sentence: imagine being afraid to think
# Translated (HE): דמיין לפחד לחשוב
# Intended (HE): מפחד
# Similarity: 0.7202 — ❌ SKIP
#
# ✔️ HUNGRY found via direct match: 'רעב' in 'כולם רעבים'
#
# Word: thrilled
# Original Sentence: mad enough to kill and thrilled
# Translated (HE): מטורף מספיק כדי להרוג ולהתרגש
# Intended (HE): נרגש מאוד
# Similarity: 0.8288 — ✔️ KEEP
#
# ✔️ HANDS found via direct match: 'ידיים' in 'אתה לא יכול להסתתר מאחורי הידיים שלך'
#
# ✔️ EYES found via direct match: 'עיניים' in 'אל תעצור את העיניים'
#
# ✔️ FINGER found via direct match: 'אצבע' in 'אתה מתנדנד לאצבעך כל מה שאתה אוהב'
#
# Word: legs
# Original Sentence: i trust your piano legs are covered up again
# Translated (HE): אני סומך על רגלי הפסנתר שלך מכוסות שוב
# Intended (HE): רגליים
# Similarity: 0.7607 — ✔️ KEEP
#
# ✔️ LOVE found via direct match: 'אהבה' in 'מאהבה למלחמה'
#
# ✔️ ANGRY found via direct match: 'כועס' in 'וכועס על גאווה כי אלוהים נמצא בצד שלנו'
#
# ✔️ DOUBTS found via direct match: 'ספקות' in 'כל הספקות שהיו לנו'
#
# Word: satisfied
# Original Sentence: and satisfied there is no other
# Translated (HE): ומרוצה שאין אחר
# Intended (HE): מסופק
# Similarity: 0.8596 — ✔️ KEEP
#
# Word: desire
# Original Sentence: born in a time that sanctions all desire
# Translated (HE): נולד בתקופה שסנקציות כל הרצון
# Intended (HE): תשוקה
# Similarity: 0.7929 — ✔️ KEEP
#
# ✔️ LOVE found via direct match: 'אהבה' in 'כמו אהבה והרס לשמות אבל שניים'
#
# Word: addiction
# Original Sentence: it addiction it obsession it a need to be me
# Translated (HE): זה התמכר לזה לאובססיה זה צורך להיות אני
# Intended (HE): התמכרות
# Similarity: 0.8198 — ✔️ KEEP
#
# ✔️ LOST found via direct match: 'אבוד' in 'אבוד יותר שאני נמצא'
#
# ✔️ LOVE found via direct match: 'אהבה' in 'רק לרגע אני בזרועות האהבה'
#
# ✔️ SHAME found via direct match: 'בושה' in 'מזהה מסתתר בבושה במשך שנים כשסיימתי'
#
# ✔️ DESPAIR found via direct match: 'ייאוש' in 'גדולי העולם היו תולים את ראשם בייאוש'
#
# ✔️ TRAVEL found via direct match: 'נסיעה' in 'להפליג במעלה הנחל נסיעה עד כה'
#
# ✔️ SAIL found via direct match: 'להפליג' in 'להפליג במעלה הנחל נסיעה עד כה'
#
# ✔️ BOAT found via direct match: 'סירה' in 'אבל תמיד צא מהסירה'
#
# ✔️ CAR found via direct match: 'מכונית' in 'דרייב קליפורניה על ידי צילום סרט מהמכונית'
#
# ✔️ TRIP found via direct match: 'טיול' in 'משם להרפתקה טיול של חיים שלמים של גילוי'
#
# Word: rocket
# Original Sentence: church by the road like rockets pointing at the stars
# Translated (HE): כנסייה בדרך כמו רקטות המצביעות על הכוכבים
# Intended (HE): טיל
# Similarity: 0.6293 — ❌ SKIP
#
# Word: rockets
# Original Sentence: church by the road like rockets pointing at the stars
# Translated (HE): כנסייה בדרך כמו רקטות המצביעות על הכוכבים
# Intended (HE): טילים
# Similarity: 0.7800 — ✔️ KEEP
#
# Word: road
# Original Sentence: church by the road like rockets pointing at the stars
# Translated (HE): כנסייה בדרך כמו רקטות המצביעות על הכוכבים
# Intended (HE): כביש
# Similarity: 0.7064 — ❌ SKIP
#
# Word: ship
# Original Sentence: the rocket ships of la jolla are waiting to blast away blast away
# Translated (HE): ספינות הרקטות של לה ג'ולה מחכות להתפוצץ משם
# Intended (HE): ספינה
# Similarity: 0.7458 — ❌ SKIP
#
# ✔️ SHIPS found via direct match: 'ספינות' in 'ספינות הרקטות של לה ג'ולה מחכות להתפוצץ משם'
#
# ✔️ SAD found via direct match: 'עצוב' in 'מה התחושה שלך עכשיו שמחה או עצובה איכשהו'
#
# ✔️ FEELING found via direct match: 'תחושה' in 'מה התחושה שלך עכשיו שמחה או עצובה איכשהו'
#
# ✔️ JEALOUS found via direct match: 'מקנא' in 'האם אתה מקנא עדיין סופר קנאי'
#
# ✔️ BLOOD found via direct match: 'דם' in 'הדם שלך דק האספירין פשוט נכנס פנימה'
#
# Word: lips
# Original Sentence: and so i stitch my lips
# Translated (HE): וכך אני תופר את שפתיי
# Intended (HE): שפתיים
# Similarity: 0.8891 — ✔️ KEEP
#
# Word: lip
# Original Sentence: and so i stitch my lips
# Translated (HE): וכך אני תופר את שפתיי
# Intended (HE): שפה
# Similarity: 0.7234 — ❌ SKIP
#
# ✔️ HOME found via direct match: 'בית' in 'פשוט קח אותי איתך הביתה'
#
# ✔️ DAD found via direct match: 'אבא' in 'אבא מאפשר לשמור על זה בינינו'
#
# ✔️ MOM found via direct match: 'אמא' in 'ואל תגיד לאמא כי פגז צועק'
#
# ...
#
# ✔️ LOST found via direct match: 'אבוד' in 'הם פשוט אבודים'
#
# Word: hate
# Original Sentence: i hate when i backslide i pray i change that
# Translated (HE): אני שונא כשאני מגלש בחזרה אני מתפלל שאשנה את זה
# Intended (HE): שנאה
# Similarity: 0.6711 — ❌ SKIP
#
# ✔️ LONELY found via direct match: 'בודד' in 'ואני מסרב להיות הבחור הבודד הזקן בבית שצפה בפורנו'
#
# ✔️ HOME found via direct match: 'בית' in 'ואני מסרב להיות הבחור הבודד הזקן בבית שצפה בפורנו'
#
# ✔️ MARRIAGE found via direct match: 'נישואין' in 'תראה את כל מה שאני יודע זה פופ נישואין ואמהות עשו את זה'
#
# ✔️ CHILDREN found via direct match: 'ילדים' in 'והילדים שאנו מכניסים לאיחוד זה'
#
# ✔️ CHILD found via direct match: 'ילד' in 'והילדים שאנו מכניסים לאיחוד זה'
#
# ✔️ GRANDPARENTS found via direct match: 'סבא וסבתא' in 'סבא וסבתא עשו את זה שניהם נשארו מחויבים'
#
# ✔️ GAME found via direct match: 'משחק' in 'פתחתי את ליבי והתחלתי את משחק הספיטין'
#
# Word: track
# Original Sentence: i hope theyre on the same track
# Translated (HE): אני מקווה שהם נמצאים באותו מסלול
# Intended (HE): מסילה
# Similarity: 0.8281 — ✔️ KEEP
#
# Word: stadiums
# Original Sentence: picture me rockin stadiums going platinum we winnin
# Translated (HE): דמיין אותי אצטדיוני רוקין הולכים פלטינה אנחנו ווינין
# Intended (HE): אצטדיונים
# Similarity: 0.9009 — ✔️ KEEP
#
# ✔️ ICE found via direct match: 'קרח' in 'קרח סיפר סיפורים על מלחמת עיר פנימית'
#
# ✔️ BEEF found via direct match: 'בקר' in 'אבל כל אחד יכול להשיג את זה אם יש בשר בקר'
#
# ✔️ JAM found via direct match: 'ריבה' in '93 עד אינסוף הוא עדיין הריבה'
#
# Word: thankful
# Original Sentence: so pardon me but im thankful for that
# Translated (HE): אז סליחה אבל אני אסיר תודה על כך
# Intended (HE): מלא תודה
# Similarity: 0.8791 — ✔️ KEEP
#
# Word: kind
# Original Sentence: it fucked up but it kind of funny
# Translated (HE): זה דפוק אבל זה די מצחיק
# Intended (HE): אדיב
# Similarity: 0.7465 — ❌ SKIP
#
# ✔️ FURIOUS found via direct match: 'זועם' in 'שנים אחר כך משחק העט זועם'
#
# ✔️ LOVE found via direct match: 'אהבה' in 'אהבה לאזור המפרץ שלי FAM'
#
# ✔️ PROUD found via direct match: 'גאה' in 'ראה IM מהחוף המערבי ואני כל כך גאה'
#
# Word: throw
# Original Sentence: throw up your w and it dont stop
# Translated (HE): זרוק את ה- W שלך וזה לא מפסיק
# Intended (HE): זריקה
# Similarity: 0.8752 — ✔️ KEEP
#
# Word: target
# Original Sentence: niggas be scrapping in the parking lot at target
# Translated (HE): כושי יגרדו בחניון ב- Target
# Intended (HE): מטרה
# Similarity: 0.7065 — ❌ SKIP
#
# ✔️ SKATERS found via direct match: 'מחליקים' in 'הם עדיין מתנדנדים עבור הסטונרים והמחליקים'
#
# ✔️ GAME found via direct match: 'משחק' in 'שנים אחר כך משחק העט זועם'
#
# ✔️ DOUBT found via direct match: 'ספק' in 'לכל מי שחשב שהממש אבד ונאלץ לחיות בספק'
#
# Word: lost
# Original Sentence: to all who thought the real was lost and had to live in doubt
# Translated (HE): לכל מי שחשב שהממש אבד ונאלץ לחיות בספק
# Intended (HE): אבוד
# Similarity: 0.7541 — ✔️ KEEP
# Translation failed (attempt 1): The read operation timed out
#
# Word: love
# Original Sentence: it love or rockets dude
# Translated (HE): זה אוהב או רקטות אחי
# Intended (HE): אהבה
# Similarity: 0.7981 — ✔️ KEEP
#
# ✔️ ENERGETIC found via direct match: 'אנרגטי' in 'עוסק בצורה זו של טרנספורמציה אנרגטית'
#
# ✔️ RESPECTED found via direct match: 'מכובד' in 'מיוצג לשחזר את הרשומות שלי בשיעורים מכובדים'
#
# ✔️ ROCKET found via direct match: 'טיל' in 'להכין ספינת טילים מתוך בית הספר הישן אימפאלס'
#
# Word: rockets
# Original Sentence: it love or rockets dude
# Translated (HE): זה אוהב או רקטות אחי
# Intended (HE): טילים
# Similarity: 0.8568 — ✔️ KEEP
#
# ✔️ ROAD found via direct match: 'כביש' in 'כמה שניות מהכביש הראשי'
#
# ✔️ PASSENGERS found via direct match: 'נוסעים' in 'ואני יורה התלקחויות סולאריות על הנוסעים שלך בשביל הכיף'
#
# ✔️ ROUTE found via direct match: 'מסלול' in 'אני גן עדן כבול אבל אני חושב שמצאתי מסלול אחר'
#
# Word: ship
# Original Sentence: to make a rocket ship out of old school impalas
# Translated (HE): להכין ספינת טילים מתוך בית הספר הישן אימפאלס
# Intended (HE): ספינה
# Similarity: 0.7397 — ❌ SKIP
#
# Word: travel
# Original Sentence: i travel rainbows
# Translated (HE): אני נוסע קשתות גשם
# Intended (HE): נסיעה
# Similarity: 0.8354 — ✔️ KEEP
#
# Word: score
# Original Sentence: you had to go hard in the paint to score
# Translated (HE): היית צריך ללכת קשה בצבע כדי להבקיע
# Intended (HE): ציון
# Similarity: 0.7708 — ✔️ KEEP
#
# Word: throw
# Original Sentence: wouldnt throw a creampuff in a cupcake war
# Translated (HE): לא היה זורק קרם מלחמה במלחמת קאפקייקס
# Intended (HE): זריקה
# Similarity: 0.8095 — ✔️ KEEP
#
# Word: bow
# Original Sentence: murs bow our heads bon apetit
# Translated (HE): מור מקח את ראשנו בון יערכה
# Intended (HE): קשת
# Similarity: 0.6420 — ❌ SKIP
#
# Word: kick
# Original Sentence: all i do is kick rhymes have fun and do cool shit
# Translated (HE): כל מה שאני עושה זה לבעוט לחרוזים ליהנות ולעשות חרא מגניב
# Intended (HE): בעיטה
# Similarity: 0.7624 — ✔️ KEEP
#
# ✔️ GAME found via direct match: 'משחק' in 'עשור ופלוס במשחק קיבלתי שם'
#
# Word: lost
# Original Sentence: i lost the hair but im still on that abstract
# Translated (HE): איבדתי את השיער אבל אני עדיין על המופשט הזה
# Intended (HE): אבוד
# Similarity: 0.8021 — ✔️ KEEP
# Translation failed (attempt 1): The read operation timed out
#
# ✔️ LOVE found via direct match: 'אהבה' in 'בנייה עם האלים אהבה מהדם'
#
# ✔️ SAD found via direct match: 'עצוב' in 'מפיקים יושבים בחדרי שינה עם מסלולים עצובים'
#
# Word: hate
# Original Sentence: i know you hate it bro
# Translated (HE): אני יודע שאתה שונא את זה אחי
# Intended (HE): שנאה
# Similarity: 0.7446 — ❌ SKIP
#
# ✔️ BRAIN found via direct match: 'מוח' in 'היא נתנה לי מוח טוב כי זה היה מזל מטומטם'
#
# ✔️ HAIR found via direct match: 'שיער' in 'איבדתי את השיער אבל אני עדיין על המופשט הזה'
#
# ✔️ VEINS found via direct match: 'ורידים' in 'נוקב דרך הוורידים שלך כמו רחרח קני סוכר או ריח'
#
# ✔️ HEAD found via direct match: 'ראש' in 'היה לי את ראש האוויר הזה שהיא תמיד תוכל להעלות אותו'
#
# ✔️ BLOOD found via direct match: 'דם' in 'יאללה ותן להראות להם על הדם המערבי בצד המערבי'
#
# Word: hair
# Original Sentence: hair pulled back nails did up
# Translated (HE): ציפורניים מושכות לאחור עשו
# Intended (HE): שיער
# Similarity: 0.6471 — ❌ SKIP
#
# ✔️ NAILS found via direct match: 'ציפורניים' in 'ציפורניים מושכות לאחור עשו'
#
# Word: wedding
# Original Sentence: smoking cigarettes going hard for her wedding ring
# Translated (HE): עישון סיגריות הולך קשה לטבעת הנישואין שלה
# Intended (HE): חתונה
# Similarity: 0.7485 — ❌ SKIP
#
# ✔️ DAD found via direct match: 'אבא' in 'נפרדנו שהיא חזרה עם אבא התינוק שלה'
#
# ✔️ BABY found via direct match: 'תינוק' in '52 אוויר כחול תינוק מקסימום'
#
# Word: love
# Original Sentence: i love my job but i hate doing interviews
# Translated (HE): אני אוהב את העבודה שלי אבל אני שונא לעשות ראיונות
# Intended (HE): אהבה
# Similarity: 0.7136 — ❌ SKIP
#
# Word: in love with
# Original Sentence: i fell in love with every girl i came on
# Translated (HE): התאהבתי בכל בחורה שבאתי עליה
# Intended (HE): מאוהב ב
# Similarity: 0.8438 — ✔️ KEEP
#
# Word: hate
# Original Sentence: i love my job but i hate doing interviews
# Translated (HE): אני אוהב את העבודה שלי אבל אני שונא לעשות ראיונות
# Intended (HE): שנאה
# Similarity: 0.6287 — ❌ SKIP
#
# ✔️ BORED found via direct match: 'משועמם' in 'כי כשאני משועמם ואין לי חרא לעשות'
#
# ✔️ HOME found via direct match: 'בית' in 'אבא לא בבית הוא מוכר סמים בפינה'
#
# ✔️ CHILD found via direct match: 'ילד' in 'ילד לילה'
#
# ✔️ DADDY found via direct match: 'אבא' in 'אבא לא בבית הוא מוכר סמים בפינה'
#
# Word: family
# Original Sentence: my daddy left my family cause of rockcocaine
# Translated (HE): אבא שלי עזב את משפחתי הסיבה לרוקוקאין
# Intended (HE): משפחה
# Similarity: 0.7684 — ✔️ KEEP
#
# ✔️ DONUTS found via direct match: 'סופגניות' in 'מריח כמו קצת נקניק וקפה וסופגניות'
#
# ✔️ SAUSAGE found via direct match: 'נקניק' in 'מריח כמו קצת נקניק וקפה וסופגניות'
#
# ✔️ COFFEE found via direct match: 'קפה' in 'מריח כמו קצת נקניק וקפה וסופגניות'
#
# ✔️ HOME found via direct match: 'בית' in 'אני שולח מעט אחר כך כדי לוודא שהיא תגיע הביתה'
#
# Word: brothers
# Original Sentence: went to her crib and her brothers pulled a strap
# Translated (HE): הלכה לעריסה שלה ואחיה משכו רצועה
# Intended (HE): אחים
# Similarity: 0.7786 — ✔️ KEEP
#
# Word: baby
# Original Sentence: that when leti texted me saying i love you baby
# Translated (HE): זה כשלטי טקסט אותי אומר שאני אוהב אותך מותק
# Intended (HE): תינוק
# Similarity: 0.7814 — ✔️ KEEP
#
# Word: hate
# Original Sentence: but imma say something that he might hate to hear
# Translated (HE): אבל אימא תגיד משהו שהוא עלול לשנוא לשמוע
# Intended (HE): שנאה
# Similarity: 0.6736 — ❌ SKIP
#
# ✔️ BRAVE found via direct match: 'אמיץ' in 'זה יכול לגרום לגבר אמיץ זה יכול להפוך גבר לעבד'
#
# Word: confused
# Original Sentence: they would get confused when he okey dog crip on em
# Translated (HE): הם היו מתבלבלים כאשר הוא אוקי כלב נצץ ב
# Intended (HE): מבולבל
# Similarity: 0.8577 — ✔️ KEEP
#
# Word: touched
# Original Sentence: running credit card scams never touched a triple beam
# Translated (HE): הונאות כרטיסי אשראי מעולם לא נגעו בקורה משולשת
# Intended (HE): נרגש
# Similarity: 0.6036 — ❌ SKIP
#
# Word: love
# Original Sentence: and the one thing i love in this world above all
# Translated (HE): והדבר היחיד שאני אוהב בעולם הזה מעל הכל
# Intended (HE): אהבה
# Similarity: 0.6813 — ❌ SKIP
#
# Word: respected
# Original Sentence: the shooter is respected much less than the gladiator
# Translated (HE): היורה מכבד הרבה פחות מהגלדיאטור
# Intended (HE): מכובד
# Similarity: 0.8047 — ✔️ KEEP
#
# ✔️ ARMS found via direct match: 'זרועות' in 'הרבה גברים משתמשים בזרועות כי הם אין ידיים'
#
# ✔️ HANDS found via direct match: 'ידיים' in '30 משהו שנים ואני כאן Tryna זורק ידיים'
#
# ✔️ HAND found via direct match: 'יד' in '30 משהו שנים ואני כאן Tryna זורק ידיים'
#
# ✔️ HEAD found via direct match: 'ראש' in 'הוא הפיל את ידו על ראש כושי כלבה'
#
# Word: throw
# Original Sentence: 30 something years and im out here tryna throw hands
# Translated (HE): 30 משהו שנים ואני כאן Tryna זורק ידיים
# Intended (HE): זריקה
# Similarity: 0.7472 — ❌ SKIP
#
# Word: running
# Original Sentence: running credit card scams never touched a triple beam
# Translated (HE): הונאות כרטיסי אשראי מעולם לא נגעו בקורה משולשת
# Intended (HE): ריצה
# Similarity: 0.6018 — ❌ SKIP
#
# Word: win
# Original Sentence: you square up win some lose some
# Translated (HE): אתה מרובע מנצח כמה מפסידים כמה
# Intended (HE): לנצח
# Similarity: 0.6469 — ❌ SKIP
#
# Word: love
# Original Sentence: i love my job but i hate doing interviews
# Translated (HE): אני אוהב את העבודה שלי אבל אני שונא לעשות ראיונות
# Intended (HE): אהבה
# Similarity: 0.7136 — ❌ SKIP
#
# Word: in love with
# Original Sentence: i fell in love with every girl i came on
# Translated (HE): התאהבתי בכל בחורה שבאתי עליה
# Intended (HE): מאוהב ב
# Similarity: 0.8438 — ✔️ KEEP
#
# Word: hate
# Original Sentence: i love my job but i hate doing interviews
# Translated (HE): אני אוהב את העבודה שלי אבל אני שונא לעשות ראיונות
# Intended (HE): שנאה
# Similarity: 0.6287 — ❌ SKIP
#
# ✔️ BORED found via direct match: 'משועמם' in 'כי כשאני משועמם ואין לי חרא לעשות'
#
# ✔️ HAND found via direct match: 'יד' in 'היא לחשה לי באוזן והכניסה את הזין שלי ביד'
#
# Word: eyes
# Original Sentence: i looked into her eyes and wondered how did she taste
# Translated (HE): הסתכלתי בעיניה ותהיתי איך היא טועמת
# Intended (HE): עיניים
# Similarity: 0.8378 — ✔️ KEEP
#
# ✔️ EAR found via direct match: 'אוזן' in 'היא לחשה לי באוזן והכניסה את הזין שלי ביד'
#
# Word: waist
# Original Sentence: she had big d cups and a very small waist
# Translated (HE): היו לה כוסות D גדולות ומותניים קטנות מאוד
# Intended (HE): מותן
# Similarity: 0.7747 — ✔️ KEEP
#
# ✔️ HOME found via direct match: 'בית' in 'הילדים שלי אשתי החיים שלי הבית שלי'
#
# Word: wife
# Original Sentence: i said yes maam but i sort of have a wife
# Translated (HE): אמרתי כן מאאם אבל יש לי אשה
# Intended (HE): אישה
# Similarity: 0.8700 — ✔️ KEEP
#
# Word: baby
# Original Sentence: baby why cant you see see see
# Translated (HE): מותק למה אתה לא יכול לראות לראות לראות
# Intended (HE): תינוק
# Similarity: 0.7180 — ❌ SKIP
#
# ✔️ HOUSE found via direct match: 'בית' in 'והייתי בביתה תוך פחות משעה'
# Translation failed (attempt 1): The read operation timed out
#
# ✔️ HEELS found via direct match: 'עקבים' in 'כבר הייתי ראש מעל עקבים מהערעור שלך'
#
# ✔️ SUIT found via direct match: 'חליפה' in 'הבא אני בעניבה ובחליפה'
#
# ✔️ RING found via direct match: 'טבעת' in 'אתה לא קיבל טבעת אז הוא כנראה לא כל כך רציני'
#
# ✔️ TIE found via direct match: 'עניבה' in 'הבא אני בעניבה ובחליפה'
#
# Word: robe
# Original Sentence: she in a robe naked at the front door
# Translated (HE): היא בגלימה עירומה בדלת הכניסה
# Intended (HE): חלוק
# Similarity: 0.6869 — ❌ SKIP
#
# ✔️ SHOE found via direct match: 'נעל' in 'אחרי שנפלתי לברך אחת כאילו אני קושרת את הנעל שלי'
#
# Word: hate
# Original Sentence: hate to stare but you was lookin at me first though
# Translated (HE): שונא לבהות אבל היית מסתכל עלי קודם
# Intended (HE): שנאה
# Similarity: 0.6859 — ❌ SKIP
#
# Word: in love with
# Original Sentence: left the block and fell in love with the girl next door
# Translated (HE): עזב את הגוש והתאהב בילדה הסמוכה
# Intended (HE): מאוהב ב
# Similarity: 0.8474 — ✔️ KEEP
#
# Word: loving
# Original Sentence: the job of loving you will never be done
# Translated (HE): התפקיד לאהוב אותך לעולם לא ייעשה
# Intended (HE): אוהב
# Similarity: 0.7448 — ❌ SKIP
#
# Word: love
# Original Sentence: she loves me but i love her more
# Translated (HE): היא אוהבת אותי אבל אני אוהבת אותה יותר
# Intended (HE): אהבה
# Similarity: 0.7427 — ❌ SKIP
#
# ✔️ CURIOUS found via direct match: 'סקרן' in 'ואני פשוט סקרן אם אתה מרגיש מה אני מרגיש'
#
# Word: eye
# Original Sentence: type of dime that caught the eye of every guy in my crew
# Translated (HE): סוג אגורה שתפס את עינו של כל בחור בצוות שלי
# Intended (HE): עין
# Similarity: 0.7031 — ❌ SKIP
#
# ✔️ HEAD found via direct match: 'ראש' in 'כבר הייתי ראש מעל עקבים מהערעור שלך'
#
# ✔️ KNEE found via direct match: 'ברך' in 'אחרי שנפלתי לברך אחת כאילו אני קושרת את הנעל שלי'
#
# Word: skater
# Original Sentence: got a couple princesses and a young pro skater
# Translated (HE): יש לי כמה נסיכות ומחלקה מקצוענת צעירה
# Intended (HE): מחליק
# Similarity: 0.8242 — ✔️ KEEP
#
# ✔️ CREW found via direct match: 'צוות' in 'סוג אגורה שתפס את עינו של כל בחור בצוות שלי'
#
# ✔️ CAPTAIN found via direct match: 'קפטן' in 'העכביש שלי גוון וונתי וומן שלי אתה קפטן מארוול'
#
# Word: animals
# Original Sentence: i got animals dammit
# Translated (HE): יש לי בעלי חיים לעזאזל
# Intended (HE): חיות
# Similarity: 0.8037 — ✔️ KEEP
#
# ✔️ GORILLAS found via direct match: 'גורילות' in 'הגורילות שלי זורקות שלטי כנופיה'
#
# Word: animal
# Original Sentence: i got animals dammit
# Translated (HE): יש לי בעלי חיים לעזאזל
# Intended (HE): חיה
# Similarity: 0.7506 — ✔️ KEEP
#
# Word: bear
# Original Sentence: too many people in the street to bear witness
# Translated (HE): יותר מדי אנשים ברחוב כדי להעיד
# Intended (HE): דוב
# Similarity: 0.7255 — ❌ SKIP
#
# Word: chicken
# Original Sentence: niggas at louisiana chicken sat trippin
# Translated (HE): כושי בלואיזיאנה עוף שבת טריפין
# Intended (HE): תרנגולת
# Similarity: 0.8332 — ✔️ KEEP
#
# ✔️ ICE found via direct match: 'קרח' in 'הגעתי לעריסה וקיבלתי לי חבילת קרח'
#
# ✔️ BEEF found via direct match: 'בקר' in 'ראיתי את הכושי הראפ הזה שהייתי איתה בשר בקר'
#
# ✔️ JAM found via direct match: 'ריבה' in 'זה היה 96 וזה היה עדיין הריבה'
#
# ✔️ BLOOD found via direct match: 'דם' in 'כל הכושי בדם עומדים על הגג'
#
# ✔️ FEET found via direct match: 'רגליים' in 'לבוש בכחול מהראש לרגליים'
#
# ✔️ HEAD found via direct match: 'ראש' in 'מפיל מהמצוק על ראשו של אותו קויוטה'
#
# Word: waist
# Original Sentence: i seen one of em try to reach in his waist
# Translated (HE): ראיתי את אחד מהם מנסה להגיע במותניים שלו
# Intended (HE): מותן
# Similarity: 0.7690 — ✔️ KEEP
#
# Word: throw
# Original Sentence: my gorillas throw gang signs yall niggas cant handle it
# Translated (HE): הגורילות שלי זורקות שלטי כנופיה
# Intended (HE): זריקה
# Similarity: 0.7705 — ✔️ KEEP
#
# ✔️ STRIKE found via direct match: 'להכות' in 'הכושים האלה רוצים לעשן ממש לפני שהם הולכים להכות בחזרה'
#
# Word: teams
# Original Sentence: still see the families barbecuein drill teams
# Translated (HE): עדיין רואים את צוותי המקדח של המברקיין
# Intended (HE): קבוצות
# Similarity: 0.7920 — ✔️ KEEP
#
# Word: kick
# Original Sentence: guess you only kick it with us when you got a problem
# Translated (HE): מניח שאתה בועט איתנו רק כשקיבלת בעיה
# Intended (HE): בעיטה
# Similarity: 0.8138 — ✔️ KEEP
# ✅ Batch processed and saved: 16000 ➡ 16500

# %%
input_file = '../data/oran_filtered.csv'
df = pd.read_csv(input_file)
print(f"Total songs in dataset: {input_file}: {len(df)}")
# Out:
# Total songs in dataset: ../data/oran_filtered.csv: 2409
